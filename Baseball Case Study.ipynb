# %%
#importing the necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing the Dataset

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# We can see here little information of data thats shows 5 rows and all present columns in
#
# Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# Output: Number of predicted wins (W)

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %% [markdown]
# We can see here little information of data thats shows 5 rows and all present in columns

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# Dataset contains only numeric values, no categorical problem so it is a "Regression" problem. 'W' contains number of wins predicted, which is the target variable in the dataset.

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (30, 17)

# %%
#data type
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# all the columns having integer type data, except ERA which is consist float type data.

# %%
#number of unique values
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# Above are the number of unique values present in each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#checking the null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# It is showing that there are no null values in the dataset.

# %%
sns.heatmap(df.isnull())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\INSHIM~1\AppData\Local\Temp/ipykernel_21712/2635541062.py in <module>
# ----> 1 sns.heatmap(df.isnull())
#
# NameError: name 'sns' is not defined

# %%
import seaborn as sns

# %%
#visualizing the null values in heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# These are the columns present in the given dataset.

# %%
#unique values present in target column
df['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
#checking the empty observation
df.loc[df['W']== " "]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %% [markdown]
# It seems that there are no spaces in the dataset.

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# 1. The count is same in all the columns so there are no null values.
# 2. There is a huge differences in max and 75% percentile.
# 3. The mean is more than median in the columns AB, H, HR, SV and E which means they are skewed to right.
# 4. In the column R(Runs), columns 2B, BB, SO, RA, ER, ERA and SHO median is more than the mean, these columns are skewed to left.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Univariate Analysis

# %%
# Checking how the data has been distriubted in each column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\INSHIM~1\AppData\Local\Temp/ipykernel_21712/1674377558.py in <module>
#       1 # Checking how the data has been distriubted in each column
# ----> 2 plt.figure(figsize=(20,25), facecolor='white')
#       3 plotnumber = 1
#       4
#       5 for column in df:
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
# Checking how the data has been distriubted in each column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Almost all the columns are normally distributed.Except R, SO, CG and E.

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.boxplot(df[column], color='red')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# Outliers are present in the columns 'R', 'ERA', 'SHO', 'SV', and 'E'.

# %% [markdown]
# ### Bivariate Analysis

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs and Wins')
sns.scatterplot(df['R'],df['W'],hue=df["W"]);
plt.xlabel("Runs")
plt.ylabel("Wins")
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Wins')

# %% [markdown]
# From the above graph it confirms that as the runs increasing number of wins also increasing.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Hits and Runs')
sns.scatterplot(df['H'],df['R'],hue=df["W"]);
plt.xlabel("Hits")
plt.ylabel("Runs")
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Runs')

# %% [markdown]
# There is a weak linearity between hits and runs. but as hits increases, runs also increses.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs Allowed and Earned Runs Average')
sns.scatterplot(df['RA'],df['ERA'],hue=df['W'],palette="husl");
plt.xlabel("Runs Allowed")
plt.ylabel("Earned Run Average")
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Earned Run Average')

# %% [markdown]
# we can see the strong linearity between RA and ERA. As Runs allowed increasing the Earned run average also increasing so which means winning rate also increasing.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Walks and Wins ')
sns.lineplot(df['BB'],df['W'], color='darkorange') 
plt.xlabel("Walks")
plt.ylabel("Wins")
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Wins')

# %% [markdown]
# The winning rate of the team increases as the number of Walks increases.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between AB and Hits')
sns.scatterplot(df['AB'],df['H'],hue=df['W']);
plt.xlabel("At Bats")
plt.ylabel("Hits")
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Hits')

# %% [markdown]
# There is a weak linear relationship between the features. As the At Bats rates increases with the rate of Hits then the Wins of teams also increases.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs and Errors ')
sns.lineplot(df['R'],df['W'], color='r') 
plt.xlabel("Runs")
plt.ylabel("Errors")
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Errors')

# %% [markdown]
# More number of runs lies between the range of 650-750.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Doubles and Wins')
sns.lineplot(df['2B'],df['W'],color="green");
plt.xlabel("Doubles")
plt.ylabel("Wins")
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Wins')

# %% [markdown]
# The more number of doubles increases the number of winnings.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Stolen Bases and Wins')
sns.lineplot(df['SB'],df['W']);
plt.xlabel("Stolen Bases")
plt.ylabel("Wins")
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Wins')

# %% [markdown]
# The winning rate is high in the range of 95-105 Stolen Bases.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Saves and Wins')
sns.regplot(df['SV'],df['W'],color="pink");
plt.xlabel("Saves")
plt.ylabel("Wins")
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Wins')

# %% [markdown]
# Number of savings increases the number of winnings for the team. And it is having a positive linearity.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between ShutOuts and Wins')
sns.regplot(df['SHO'],df['W'],color="darkorange");
plt.xlabel("ShutOuts")
plt.ylabel("Wins")
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Wins')

# %% [markdown]
# when The number of shutouts is more so the winning chances also more.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Triples and Wins')
sns.regplot(df['3B'],df['W'],color="r");
plt.xlabel("Triples")
plt.ylabel("Wins")
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Wins')

# %% [markdown]
# There is a negative linear relationship between the feature 3B and the label Wins.

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(df,hue="W",palette="husl")

# %% [markdown]
# ### Checking Outliers

# %%
df.plot(kind='box',fontsize=14,figsize=(25,25), color='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in these columns- R - Runs, ERA - Earned Run Average, SHO - Shutouts, SV - Saves and E - Errors

# %% [markdown]
# ### Removing Outliers:

# %% [markdown]
# #### i) Zscore method:

# %%
# Features containing outliers
features = df[["R","ERA","SHO","SV","E"]]

# %%
from scipy.stats import zscore

z=np.abs(zscore(features))
z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\INSHIM~1\AppData\Local\Temp/ipykernel_21712/3109397648.py in <module>
#       1 from scipy.stats import zscore
#       2
# ----> 3 z=np.abs(zscore(features))
#       4 z
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
from scipy.stats import zscore

z=np.abs(zscore(features))
z
# Out:
#            R       ERA       SHO        SV         E
# 0   0.619078  0.506955  0.814629  1.671607  0.461470
# 1   0.134432  0.254598  0.172800  0.249879  0.607197
# 2   0.332906  0.641347  0.320914  0.654856  1.117242
# 3   1.146419  0.053010  0.567771  0.784104  0.485758
# 4   0.013270  1.531318  0.172800  1.042600  0.607197
# 5   3.509647  0.350165  0.320914  1.171848  0.461470
# 6   1.311430  0.165003  1.802057  0.637623  0.097152
# 7   0.428681  0.209800  0.320914  0.008617  1.262970
# 8   0.765626  0.484557  0.172800  2.188598  0.048576
# 9   1.034489  0.792164  0.320914  0.396360  0.194303
# 10  1.086415  0.635374  0.567771  0.249879  1.797303
# 11  0.705622  0.865333  0.419657  0.525608  0.680061
# 12  0.471376  0.036584  0.172800  0.379127  0.097152
# 13  0.557920  0.456185  0.172800  0.249879  0.024288
# 14  0.099814  0.411388  0.913371  1.947335  2.307348
# 15  0.713699  2.276445  0.913371  2.447094  0.121439
# 16  0.151740  1.671683  0.419657  1.413111  2.015894
# ...

# %%
# Creating new dataframe
new_df = df[(z<3).all(axis=1)]
new_df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# shape of the dataset, before removing the outliers.

# %%
new_df.shape
# Out:
# (29, 17)

# %% [markdown]
# new dataset after removing the outliers contains 29 rows and 17 columns.

# %%
# Checking the the data loss
data_loss = (30-29)/30*100
data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# data loss is less in zscore method.

# %% [markdown]
# #### ii) IQR (Inter Quantile Range) method

# %%
# 1st quantile
Q1=features.quantile(0.25)

# 3rd quantile
Q3=features.quantile(0.75)

#IQR
IQR=Q3-Q1

df1=df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
# Out:
# C:\Users\INSHIM~1\AppData\Local\Temp/ipykernel_21712/2100415156.py:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df1=df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df1.shape
# Out:
# (20, 17)

# %% [markdown]
# The new dataframe using IQR method has 20 rows and 17 columns.

# %%
# Let's check the dataloss
data_loss = (30-20)/30*100
data_loss
# Out:
# 33.33333333333333

# %% [markdown]
# Data loss is more in IQR method, so I'll go with the zscore method.

# %% [markdown]
# ### Checking for skewness

# %%
# Checking the skewness
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# The skewness present in the columns "H", "CG", "SHO", "SV" and "E"

# %% [markdown]
# ### Removing Skewness using yeo-johnson method

# %%
skewed_features=["CG","SHO","SV","E"]

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box-cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box-cox' or 'yeo-johnson'\n"

# %%
new_df[skewed_features] = scaler.fit_transform(new_df[skewed_features].values)
new_df[skewed_features].head()
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
#          CG       SHO        SV         E
# 0 -0.307098 -0.787002  1.532753 -0.348265
# 1 -0.307098  0.236737  0.312020 -0.540820
# 2  2.011315 -0.252844 -0.664137 -1.326125
# 3  1.264463 -0.513555 -0.820689  0.650818
# 4  1.264463  0.236737 -1.149165 -0.540820

# %%
new_df['H'] = np.log(new_df['H'])
# Out:
# C:\Users\INSHIM~1\AppData\Local\Temp/ipykernel_21712/145532210.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['H'] = np.log(new_df['H'])

# %%
# Now let's check the skewness after using the transformation
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738423
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# To remove skewness by using yeo-johnson method I am getting zero values in the column "H" and showing NAN values. by using logp method only 0.02 skewness can reduce from H column. "H" might have some relation with the target and will remove this column if necessary in further steps.

# %%
# After removing let's check how the data has been distributed in each column.

features_skewed = ["H","CG", "SHO", "SV", "E"]
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in new_df[features_skewed]:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(new_df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\inshimpin\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# We can see the data is normally distributed and skewness is also removed. I used all the possible methods to remove the skewness but the column "H" still has skewness. First will check the correlation with the target, if there is necessary will drop this column.

# %% [markdown]
# ### Correlation between the target variable and independent variables using HEAT map.

# %%
# Checking the correlation between features and the target
cor = new_df.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780 -0.020787  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.432235  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.770155  0.490752  0.445604 -0.064653
# H   -0.020787  0.432235  0.770155  1.000000  0.527354  0.579733 -0.219201
# 2B   0.384886  0.469293  0.490752  0.527354  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.579733  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.219201 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.221773  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.373302 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674  0.420201  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499  0.243639 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.279955 -0.224993  0.333731 -0.062094
# ...

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(16,9))
sns.heatmap(new_df.corr(),linewidths=.1,annot=True)
plt.yticks(rotation=0);

# %% [markdown]
# This heat map contains both positive and negative correlation.
#
# 1. The target "W" is positively correlated with the features "SV", "SHO", "BB", "HR", "2B", "R" and "SO" .
# 2. The target "W" is highly negatively correlated with the features "ERA","ER" and "RA".
# 3. RA, ER and ERA are higly correlated with each other.Which can causes multicollinearity problem, to avoid this problem will check VIF value and will drop the columns if necessary.

# %%
cor['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.756713
# SHO    0.481626
# BB     0.447513
# R      0.390451
# 2B     0.384886
# HR     0.245697
# SO     0.156469
# CG     0.007696
# H     -0.020787
# E     -0.079633
# AB    -0.085780
# SB    -0.169503
# 3B    -0.206737
# ER    -0.815308
# RA    -0.823176
# ERA   -0.826952
# Name: W, dtype: float64

# %% [markdown]
# ### Visualizing the correlation between label and features using bar plot

# %%
plt.figure(figsize=(22,7))
new_df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('target',fontsize=14)
plt.title('correlation between label and feature using bar plot',fontsize=18)
plt.show()

# %% [markdown]
# Here the feature "H" and "CG" has very less correaltion with the label. we can drop them.

# %%
new_df.drop("H", axis=1, inplace=True)
# Out:
# C:\Users\inshimpin\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
new_df.drop("CG", axis=1, inplace=True)

# %%
new_df.head()
# Out:
#     W    R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA       SHO  \
# 0  95  724  5575  300  42  139  383   973  104  641  601  3.73 -0.787002
# 1  83  696  5467  277  44  156  439  1264   70  700  653  4.07  0.236737
# 2  81  669  5439  303  29  141  533  1157   86  640  584  3.67 -0.252844
# 3  76  622  5533  260  27  136  404  1231   68  701  643  3.98 -0.513555
# 4  74  689  5605  289  49  151  455  1259   83  803  746  4.64  0.236737
#
#          SV         E
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# 2 -0.664137 -1.326125
# 3 -0.820689  0.650818
# 4 -1.149165 -0.540820

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Separating the independent and target variables into x and y

# %%
x=new_df.drop("W", axis=1)
y=new_df["W"]

# %%
x.shape
# Out:
# (29, 14)

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# ### Scaling data using StandardScaler:

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#            R        AB        2B        3B        HR        BB        SO  \
# 0   0.959398  0.830084  1.556538  1.010845 -0.765863 -1.536359 -2.727623
# 1   0.331147 -0.702831  0.201171  1.208917 -0.181389 -0.495021  0.121896
# 2  -0.274666 -1.100253  1.733325 -0.276617 -0.697101  1.252941 -0.925866
# 3  -1.329231  0.233951 -0.800621 -0.474688 -0.869006 -1.145857 -0.201246
# 4   0.174084  1.255894  0.908319  1.704094 -0.353293 -0.197495  0.072935
# 5   1.856900  0.716535 -0.093474 -1.266972  1.743939  1.643442 -0.240414
# 6   0.712585 -0.447345 -1.625627 -1.167936  1.915843 -0.885522  0.777970
# 7  -0.835605 -0.447345  0.260100  0.020490  0.196801 -0.550807  0.572335
# 8   1.497899  1.752672  1.202964  0.119526 -0.009484  0.230197 -1.013995
# 9   1.565212 -0.078310  0.319029  0.020490  0.368705  0.695081 -0.181661
# 10  1.071586 -0.816380  0.260100 -0.573723  2.362794  0.378960  1.375292
# 11 -0.454167 -1.412514 -1.802414 -1.068901  0.506228 -0.569402 -0.994411
# ...

# %% [markdown]
# ### Checking VIF values to solve multicollinearity

# %%
# Finding varience inflation factor in each scaled column i.e, x.shape[1] (1/(1-R2))

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#      VIF values Features
# 0      6.219825        R
# 1      9.828077       AB
# 2      2.683572       2B
# 3      3.196853       3B
# 4      7.369072       HR
# 5      2.686472       BB
# 6      2.741072       SO
# 7      1.757901       SB
# 8    179.096825       RA
# 9   1754.643859       ER
# 10  1310.260128      ERA
# 11     3.086344      SHO
# 12     4.021573       SV
# 13     1.742105        E

# %% [markdown]
# The VIF value is more than 10 in the columns "RA", "ER", "ERA". Let's drop the RA and ER columns to avoid multicolinearity.

# %%
x.drop("ER", axis=1, inplace=True)

# %%
# Againing checking the VIF after removing one column
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#     VIF values Features
# 0     4.352902        R
# 1     3.177214       AB
# 2     2.597985       2B
# 3     3.072775       3B
# 4     4.949255       HR
# 5     2.561982       BB
# 6     2.661842       SO
# 7     1.680467       SB
# 8   119.939744       RA
# 9   111.859162      ERA
# 10    2.932319      SHO
# 11    2.112465       SV
# 12    1.742101        E

# %%
x.drop("RA", axis=1, inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#     VIF values Features
# 0     4.250076        R
# 1     2.238746       AB
# 2     2.597917       2B
# 3     3.030073       3B
# 4     4.562014       HR
# 5     2.222720       BB
# 6     2.042786       SO
# 7     1.568151       SB
# 8     3.878177      ERA
# 9     2.651314      SHO
# 10    1.954370       SV
# 11    1.493128        E

# %% [markdown]
# Now we can observe all the values are less than 10 which means we have solved the multicollinearity problem. let's move to model building.

# %% [markdown]
# ### Modeling

# %% [markdown]
# #### Finding best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state=i)
    mod = LinearRegression()
    mod.fit(x_train, y_train)
    pred = mod.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.9291790579976077  on Random_state  50

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)

# %% [markdown]
# ### Regression Algorithms

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %% [markdown]
# ### Linear Regression

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
print('R2_score:',r2_score(y_test,predLR))
print('MAE:',metrics.mean_absolute_error(y_test, predLR))
print('MSE:',metrics.mean_squared_error(y_test, predLR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predLR)))
# Out:
# R2_score: 0.9291790579976077
# MAE: 2.4627865987898443
# MSE: 10.163242343651952
# RMSE: 3.187984056367276

# %% [markdown]
# The R2 score for Linear Regression is 92.9%.

# %% [markdown]
# ### Lasso Regressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
lasso=Lasso()
clf=GridSearchCV(lasso,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
lasso=Lasso(alpha=1,random_state=0)
lasso.fit(x_train,y_train)
lasso.score(x_train,y_train)
pred_lasso=lasso.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_lasso))
print('MAE:',metrics.mean_absolute_error(y_test, pred_lasso))
print('MSE:',metrics.mean_squared_error(y_test, pred_lasso))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_Score: 0.8642951302468397
# MAE: 3.8253497504300973
# MSE: 19.4744864939597
# RMSE: 4.41299065192299

# %% [markdown]
# The R2 score for Lasso Regressor is 86.4%.

# %% [markdown]
# ### Ridge Regressor

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
paramsRidge = {'alpha':[0.01, 0.1, 1.0,10.26], 'solver' : ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}
ridge=Ridge()
clf=GridSearchCV(ridge,paramsRidge)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10.26, 'solver': 'saga'}

# %%
# Checking R2 score for Ridge regressor
ridge=Ridge(alpha=10.26,solver='svd')
ridge.fit(x_train,y_train)
ridge.score(x_train,y_train)
pred_ridge=ridge.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_ridge))
print('MAE:',metrics.mean_absolute_error(y_test, pred_ridge))
print('MSE:',metrics.mean_squared_error(y_test, pred_ridge))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred_ridge)))
# Out:
# R2_Score: 0.8226737478988199
# MAE: 4.388774985185979
# MSE: 25.4474117830138
# RMSE: 5.044542772443683

# %% [markdown]
# The R2 score for Ridge Regressor is 82.2%.

# %% [markdown]
# ### Stochastic Gradient Descent Regressor

# %%
SGD=SGDRegressor()
SGD.fit(x_train,y_train)

predSGD=SGD.predict(x_test)
print('R2_Score:',r2_score(y_test,predSGD))
print('MAE:',metrics.mean_absolute_error(y_test, predSGD))
print('MSE:',metrics.mean_squared_error(y_test, predSGD))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predSGD)))
# Out:
# R2_Score: 0.927993315142041
# MAE: 2.781222846997044
# MSE: 10.33340376282612
# RMSE: 3.214561208442938

# %% [markdown]
# The R2 score for Stochastic Gradient Descent Regressor is 92.8%.

# %% [markdown]
# ### Checking the cross validation score

# %%
from sklearn.model_selection import cross_val_score

# %%
# Checking cv score for Linear Regression
print(cross_val_score(LR,x,y,cv=5).mean())
# Out:
# 0.37344412304899344

# %%
# Checking cv score for Lasso Regression
print(cross_val_score(lasso,x,y,cv=5).mean())
# Out:
# 0.5206537019436117

# %%
# Checking cv score for Ridge Regression
print(cross_val_score(ridge,x,y,cv=5).mean())
# Out:
# 0.3495949199274463

# %%
# Checking cv score for SGD Regression
print(cross_val_score(SGD,x,y,cv=5).mean())
# Out:
# 0.2707588631906136

# %% [markdown]
# From the difference of both R2 score and Cross Validation score we can conclude that Lasso Rgressor as our best fitting model.

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Lasso Regressor
parameters = {'alpha':[0.01, 0.1, 1.0,10.26],
              'selection':['cyclic','random'],
              'max_iter':[2,4,6,8,10],
              'tol':[100,1000],
              'fit_intercept':['bool']}

# %%
GCV=GridSearchCV(Lasso(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GCV.best_params_
# Out:
# {'alpha': 0.1,
#  'fit_intercept': 'bool',
#  'max_iter': 2,
#  'selection': 'random',
#  'tol': 1000}

# %% [markdown]
# This gives the best parameter value.

# %%
# Creating final model
BaseBall = Lasso(alpha=1.0, fit_intercept="bool", max_iter=2, selection="random", tol=100)
BaseBall.fit(x_train, y_train)
pred = BaseBall.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_lasso)*100)
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_Score: 86.42951302468397
# RMSE value: 4.41299065192299

# %% [markdown]
# ### Saving the model

# %%
# Saving the model using .pkl
import joblib
joblib.dump(BaseBall,"BaseBall_Case_Study.pkl")
# Out:
# ['BaseBall_Case_Study.pkl']

# %% [markdown]
# I have saved my model using joblib.

# %%
# Loading the saved model
model=joblib.load("BaseBall_Case_Study.pkl")

#Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([77.70179898, 84.28067086, 75.10902815, 87.14946526, 75.36569222,
#        71.07985112, 85.57712524, 86.19956073, 88.90454851])

# %% [markdown]
# These are the predicted values

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                    0          1          2          3          4          5  \
# Predicted  77.701799  84.280671  75.109028  87.149465  75.365692  71.079851
# Original   68.000000  78.000000  74.000000  88.000000  68.000000  64.000000
#
#                    6          7           8
# Predicted  85.577125  86.199561   88.904549
# Original   92.000000  90.000000  100.000000
